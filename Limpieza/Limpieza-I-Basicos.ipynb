# %% [markdown]
# # Limpieza I

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Cambiar-el-nombre-de-las-columnas" data-toc-modified-id="Cambiar-el-nombre-de-las-columnas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Cambiar el nombre de las columnas</a></span></li><li><span><a href="#Duplicados" data-toc-modified-id="Duplicados-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Duplicados</a></span></li><li><span><a href="#Variables-redundantes" data-toc-modified-id="Variables-redundantes-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Variables redundantes</a></span></li><li><span><a href="#Cambio-del-tipo-de-columna" data-toc-modified-id="Cambio-del-tipo-de-columna-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Cambio del tipo de columna</a></span><ul class="toc-item"><li><span><a href="#Floats-que-deberían-ser-Integers" data-toc-modified-id="Floats-que-deberían-ser-Integers-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><em>Floats</em> que deberían ser <em>integers</em></a></span></li><li><span><a href="#Strings-que-deberían-ser-decimales" data-toc-modified-id="Strings-que-deberían-ser-decimales-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span><em>Strings</em> que deberían ser decimales</a></span></li></ul></li><li><span><a href="#Orden-columnas" data-toc-modified-id="Orden-columnas-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Ordenar columnas</a></span><ul class="toc-item"><li><span><a href="#Cambiar-una-columna-al-índice:" data-toc-modified-id="Cambiar-una-columna-al-índice:-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Cambiar una columna al índice</a></span></li><li><span><a href="#Cambiar-el-orden-de-nuestras-columnas" data-toc-modified-id="Cambiar-el-orden-de-nuestras-columnas-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Cambiar el orden de nuestras columnas</a></span></li></ul></li></ul></div>

# %%
import pandas as pd

# %% [markdown]
# La limpieza de datos (también lo encontraréis como *data cleansing*, *data cleaning* o *data scrubbing*) es el proceso de analizar datos para encontrar valores incorrectos, corruptos y faltantes y eliminarlos para que sean adecuados para la entrada del análisis de datos.
#
# Si bien no hay reglas establecidas a seguir para la limpieza de datos, a lo largo de los próximos días veremos los principales "cambios" que tenemos que llevar a cabo en nuestro *DataFrame* para alcanzar nuestro objetivo.
#
# **Los principales motivos por los que podemos tener nuestros datos "sucios" podrían ser:**
#
# - Los datos se recopilan de varias fuentes estructuradas y no estructuradas y luego se combinan, dando lugar a valores duplicados y mal etiquetados.
#
#
# - Error de entrada manual / errores tipográficos.
#
#
# - Capitalización incorrecta.
#
#
# - Categorías / clases mal etiquetadas.
#
# > Siempre debemos recordar que lo más importante es la calidad de nuestros datos!

# %%
df = pd.read_csv("files/WDICountry2.csv", index_col = 0)
df.head(2)
# Out:
#   Country Name m2016 f2016  index_ Country Code Short Name Table Name  \
# 0        Aruba   NaN   1,8       0          ABW      Aruba      Aruba
# 1        Aruba   NaN   1,8       0          ABW      Aruba      Aruba
#
#   Long Name 2-alpha code  Currency Unit  ... Latest population census  \
# 0     Aruba           AW  Aruban florin  ...          2020 (expected)
# 1     Aruba           AW  Aruban florin  ...          2020 (expected)
#
#   Latest household survey Source of most recent Income and expenditure data  \
# 0                     NaN                                               NaN
# 1                     NaN                                               NaN
#
#   Vital registration complete Latest agricultural census  \
# 0                         Yes                        NaN
# 1                         Yes                        NaN
#
#    Latest industrial data Latest trade data Unnamed: 30 mean_age total2016
# 0                     NaN            2018.0         NaN       37    622308
# 1                     NaN            2018.0         NaN       57   4771070
#
# [2 rows x 37 columns]

# %% [markdown]
# Como vemos no podemos ver el total de las columnas que tenemos en el *DataFrame*. Recordamos que tenemos un método de Pandas que nos va a permitir visualizar todas las columnas 👇:

# %%
pd.options.display.max_columns = None

# %%
# yujuu! ya podemos ver todas las columnas

df.head(2)
# Out:
#   Country Name m2016 f2016  index_ Country Code Short Name Table Name  \
# 0        Aruba   NaN   1,8       0          ABW      Aruba      Aruba
# 1        Aruba   NaN   1,8       0          ABW      Aruba      Aruba
#
#   Long Name 2-alpha code  Currency Unit Special Notes  \
# 0     Aruba           AW  Aruban florin           NaN
# 1     Aruba           AW  Aruban florin           NaN
#
#                       Region Income Group WB-2 code  \
# 0  Latin America & Caribbean  High income        AW
# 1  Latin America & Caribbean  High income        AW
#
#   National accounts base year  National accounts reference year  \
# 0                        2000                               NaN
# 1                        2000                               NaN
#
#                  SNA price valuation Lending category Other groups  \
# 0  Value added at basic prices (VAB)              NaN          NaN
# 1  Value added at basic prices (VAB)              NaN          NaN
#
#                          System of National Accounts  \
# 0  Country uses the 1993 System of National Accou...
# 1  Country uses the 1993 System of National Accou...
#
#   Alternative conversion factor  PPP survey year  \
# 0                           NaN              NaN
# 1                           NaN              NaN
#
#   Balance of Payments Manual in use External debt Reporting status  \
# 0                              BPM6                            NaN
# 1                              BPM6                            NaN
#
#         System of trade Government Accounting concept  \
# 0  General trade system                           NaN
# 1  General trade system                           NaN
#
#                      IMF data dissemination standard Latest population census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 1  Enhanced General Data Dissemination System (e-...          2020 (expected)
#
#   Latest household survey Source of most recent Income and expenditure data  \
# 0                     NaN                                               NaN
# 1                     NaN                                               NaN
#
#   Vital registration complete Latest agricultural census  \
# 0                         Yes                        NaN
# 1                         Yes                        NaN
#
#    Latest industrial data  Latest trade data  Unnamed: 30  mean_age  total2016
# 0                     NaN             2018.0          NaN        37     622308
# 1                     NaN             2018.0          NaN        57    4771070

# %% [markdown]
# ## Cambiar el nombre de las columnas
#
# Como podemos ver, nuestras columnas están en mayúsculas y minúsculas, tienen espacios etc. Esto puede resultar algo incómodo cuando trabajemos con ellas. Es por esto que debemos acostumbrarnos a homogeneizar el nombre de las columnas.
#
# Si recordamos, cuando vimos Pandas aprendimos el método `.rename()` que nos permitía cambiar el nombre de las columnas de nuestro *DataFrame* usando un diccionario.
#
# Su sintaxis era:
#
# ```python
#     MiDataFrame.rename(columns, inplace)
# ```
#
# Donde:
#
# - `columns`: será un diccionario donde las *keys* serán el nombre de las columnas antiguas y los *values* los nombres de las columnas nuevas.
# - `inplace`: si es `True` lo que haremos será guardar los cambios en el *DataFrame* original.

# %% [markdown]
# Vamos a poner todos los nombres de las columnas en minúscula (usando el método `.lower()`) y sustituiremos los espacios por barras bajas (usando el método `.replace()`). Recordamos que tenemos 32 columnas, hacer esto una a una puede resultar algo tedioso, por lo que haremos un *dict comprehension*.

# %%
# crearemos un diccionario con el dict comprehension

nuevas_columnas = {col: col.replace(" ", "_").lower() for col in df.columns}
nuevas_columnas
# Out:
# {'Country Name': 'country_name',
#  'm2016': 'm2016',
#  'f2016': 'f2016',
#  'index_': 'index_',
#  'Country Code': 'country_code',
#  'Short Name': 'short_name',
#  'Table Name': 'table_name',
#  'Long Name': 'long_name',
#  '2-alpha code': '2-alpha_code',
#  'Currency Unit': 'currency_unit',
#  'Special Notes': 'special_notes',
#  'Region': 'region',
#  'Income Group': 'income_group',
#  'WB-2 code': 'wb-2_code',
#  'National accounts base year': 'national_accounts_base_year',
#  'National accounts reference year': 'national_accounts_reference_year',
#  'SNA price valuation': 'sna_price_valuation',
#  'Lending category': 'lending_category',
#  'Other groups': 'other_groups',
#  'System of National Accounts': 'system_of_national_accounts',
#  'Alternative conversion factor': 'alternative_conversion_factor',
#  'PPP survey year': 'ppp_survey_year',
#  'Balance of Payments Manual in use': 'balance_of_payments_manual_in_use',
#  'External debt Reporting status': 'external_debt_reporting_status',
#  'System of trade': 'system_of_trade',
#  'Government Accounting concept': 'government_accounting_concept',
#  'IMF data dissemination standard': 'imf_data_dissemination_standard',
#  'Latest population census': 'latest_population_census',
#  'Latest household survey': 'latest_household_survey',
#  'Source of most recent Income and expenditure data': 'source_of_most_recent_income_and_expenditure_data',
#  'Vital registration complete': 'vital_registration_complete',
#  'Latest agricultural census': 'latest_agricultural_census',
#  'Latest industrial data': 'latest_industrial_data',
#  'Latest trade data': 'latest_trade_data',
#  'Unnamed: 30': 'unnamed:_30',
#  'mean_age': 'mean_age',
#  'total2016': 'total2016'}

# %%
# aplicamos el método rename

df.rename(columns = nuevas_columnas, inplace = True)

# %%
# chequeamos que se han hecho los cambios

df.head(2)
# Out:
#   country_name m2016 f2016  index_ country_code short_name table_name  \
# 0        Aruba   NaN   1,8       0          ABW      Aruba      Aruba
# 1        Aruba   NaN   1,8       0          ABW      Aruba      Aruba
#
#   long_name 2-alpha_code  currency_unit special_notes  \
# 0     Aruba           AW  Aruban florin           NaN
# 1     Aruba           AW  Aruban florin           NaN
#
#                       region income_group wb-2_code  \
# 0  Latin America & Caribbean  High income        AW
# 1  Latin America & Caribbean  High income        AW
#
#   national_accounts_base_year  national_accounts_reference_year  \
# 0                        2000                               NaN
# 1                        2000                               NaN
#
#                  sna_price_valuation lending_category other_groups  \
# 0  Value added at basic prices (VAB)              NaN          NaN
# 1  Value added at basic prices (VAB)              NaN          NaN
#
#                          system_of_national_accounts  \
# 0  Country uses the 1993 System of National Accou...
# 1  Country uses the 1993 System of National Accou...
#
#   alternative_conversion_factor  ppp_survey_year  \
# 0                           NaN              NaN
# 1                           NaN              NaN
#
#   balance_of_payments_manual_in_use external_debt_reporting_status  \
# 0                              BPM6                            NaN
# 1                              BPM6                            NaN
#
#         system_of_trade government_accounting_concept  \
# 0  General trade system                           NaN
# 1  General trade system                           NaN
#
#                      imf_data_dissemination_standard latest_population_census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 1  Enhanced General Data Dissemination System (e-...          2020 (expected)
#
#   latest_household_survey source_of_most_recent_income_and_expenditure_data  \
# 0                     NaN                                               NaN
# 1                     NaN                                               NaN
#
#   vital_registration_complete latest_agricultural_census  \
# 0                         Yes                        NaN
# 1                         Yes                        NaN
#
#    latest_industrial_data  latest_trade_data  unnamed:_30  mean_age  total2016
# 0                     NaN             2018.0          NaN        37     622308
# 1                     NaN             2018.0          NaN        57    4771070

# %% [markdown]
# ## Duplicados
#
# Es probable que muchos no se den cuenta inmediatamente de la importancia de encontrar y eliminar los datos duplicados. Sin embargo, es importante darse cuenta de que los datos duplicados pueden crear un caos que, a la larga, podría hacernos llegar a conclusiones erróneas, lo que sería una gran pérdida de tiempo.
#
# Identificar y eliminar o fusionar estos registros duplicados de una base de datos es una parte clave para realizar un buen análisis de datos. Las principales ventajas de eliminar los duplicados son:
#
# - Desarrollará una versión completa de la verdad de nuestros datos que nos permitirá basar las decisiones estratégicas en datos precisos.
#
# - Se ahorra tiempo al no enviar comunicaciones idénticas varias veces a la misma persona.
#
# - Nuestro análisis se vuelven más precisos.
#
# > En Pandas tenemos el método `duplicated` que nos va a permitir conocer si tenemos algún valor duplicado en nuestro *DataFrame*.
#
# La sintaxis:
#
# ```python
#     MiDataFrame.duplicated(subset, keep)
# ```
#
# Donde:
#
# - `subset`: de la subcolumna o secuencia de etiquetas, es opcional. Considera sólo determinadas columnas para identificar los duplicados, por defecto utiliza todas las columnas.
#
# - `keep`: por defecto "first". Otros valores que puede tomar:
#
#     - `first` : marca los duplicados como Verdaderos excepto la primera ocurrencia.
#     - `last` : marca los duplicados como Verdaderos excepto la última ocurrencia.
#     - `False` : marca todos los duplicados como Verdaderos.
#
#  📌 **NOTA** Nos devuelve una *Serie* de booleanos.

# %%
# chequeamos si hay valores nulos basándonos en todas las columnas

df.duplicated() # como siempre esto nos puede resultar algo difícil de interpretar
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# Length: 230, dtype: bool

# %%
# podemos incluir un sum() para que nos de el conteo de las filas que están duplicadas

df.duplicated().sum() # en total tenemos 1 filas duplicadas.
# Out:
# 0

# %%
# si quisieramos por ejemplo chequear si hay valores repetidos en función de dos columas (index y country_code8

df.duplicated(["index_", "country_code"]).sum()
# Out:
# 32

# %%
# si quisieramos extraer los valores exactos duplicados: 

df[df.duplicated(["index_", "country_code"])].head(2)
# Out:
#    country_name m2016  f2016  index_ country_code short_name table_name  \
# 1         Aruba   NaN    1,8       0          ABW      Aruba      Aruba
# 26      Bolivia  29,5  2,878      28          BOL    Bolivia    Bolivia
#
#                          long_name 2-alpha_code       currency_unit  \
# 1                            Aruba           AW       Aruban florin
# 26  Plurinational State of Bolivia           BO  Bolivian Boliviano
#
#    special_notes                     region         income_group wb-2_code  \
# 1            NaN  Latin America & Caribbean          High income        AW
# 26           NaN  Latin America & Caribbean  Lower middle income        BO
#
#    national_accounts_base_year  national_accounts_reference_year  \
# 1                         2000                               NaN
# 26                        1990                               NaN
#
#                   sna_price_valuation lending_category other_groups  \
# 1   Value added at basic prices (VAB)              NaN          NaN
# 26  Value added at basic prices (VAB)             IBRD         HIPC
#
#                           system_of_national_accounts  \
# 1   Country uses the 1993 System of National Accou...
# 26  Country uses the 1993 System of National Accou...
#
#    alternative_conversion_factor  ppp_survey_year  \
# 1                            NaN              NaN
# 26                       1960–85              NaN
#
#    balance_of_payments_manual_in_use external_debt_reporting_status  \
# 1                               BPM6                            NaN
# 26                              BPM6                         Actual
#
#          system_of_trade government_accounting_concept  \
# 1   General trade system                           NaN
# 26  General trade system                           NaN
#
#                       imf_data_dissemination_standard  \
# 1   Enhanced General Data Dissemination System (e-...
# 26  Enhanced General Data Dissemination System (e-...
#
#    latest_population_census              latest_household_survey  \
# 1           2020 (expected)                                  NaN
# 26                     2012  Demographic and Health Survey, 2008
#
#    source_of_most_recent_income_and_expenditure_data  \
# 1                                                NaN
# 26           Integrated household survey (IHS), 2016
#
#    vital_registration_complete latest_agricultural_census  \
# 1                          Yes                        NaN
# 26                         NaN                       2013
#
#     latest_industrial_data  latest_trade_data  unnamed:_30  mean_age  \
# 1                      NaN             2018.0          NaN        57
# 26                  2010.0             2018.0          NaN        64
#
#     total2016
# 1     4771070
# 26    8951334

# %% [markdown]
# Ya hemos identificado los valores duplicados, ¿cómo los eliminamos ahora?
#
# En Pandas tenemos el método `drop_duplicated()` que nos va a permitir eliminar los duplicados.
#
# ```python
#     MiDataFrame.drop_duplicates(subset, inplace, ignore_index)
# ```
#
# Donde:
#
# - `subset`: de la subcolumna o secuencia de etiquetas, es opcional. Considera sólo ciertas columnas para identificar duplicados, por defecto usa todas las columnas.
#
# - `inplace`: por defecto `False`. Si se eliminan los duplicados en su lugar o se devuelve una copia.
#
# - `ignore_index`: por defecto `False`. Será como un `.reset_index()` si lo dejamos a `False`.

# %%
df.drop_duplicates(subset = ["index_", "country_code"], inplace = True)

# %% [markdown]
# Ya hemos eliminado los duplicados, veamos si seguimos con alguno:

# %%
# genial!! Ya hemos quitado los duplicados!!!! 

df.duplicated(["index_", "country_code"]).sum()
# Out:
# 0

# %% [markdown]
# ## Variables redundantes
#
# De la misma forma que tener filas que contienen información redundante, tener columnas que nos están dando la misma información nos puede dar los mismos problemas.

# %%
# volvamos a ver nuestro dataframe: 

df.sample(2)
# Out:
#     country_name m2016 f2016  index_ country_code  short_name  table_name  \
# 105   Kazakhstan  10,1  2,73     119          KAZ  Kazakhstan  Kazakhstan
# 155        Nauru  28,5   NaN     178          NRU       Nauru       Nauru
#
#                   long_name 2-alpha_code      currency_unit  \
# 105  Republic of Kazakhstan           KZ       Kazakh tenge
# 155       Republic of Nauru           NR  Australian dollar
#
#                                          special_notes                 region  \
# 105                                                NaN  Europe & Central Asia
# 155  Fiscal year end: June 30; reporting period for...    East Asia & Pacific
#
#             income_group wb-2_code  \
# 105  Upper middle income        KZ
# 155          High income        NR
#
#                            national_accounts_base_year  \
# 105  Original chained constant price data are resca...
# 155                                               2007
#
#      national_accounts_reference_year                sna_price_valuation  \
# 105                            2005.0  Value added at basic prices (VAB)
# 155                               NaN  Value added at basic prices (VAB)
#
#     lending_category other_groups  \
# 105             IBRD          NaN
# 155             IBRD          NaN
#
#                            system_of_national_accounts  \
# 105  Country uses the 1993 System of National Accou...
# 155  Country uses the 1993 System of National Accou...
#
#     alternative_conversion_factor  ppp_survey_year  \
# 105                       1987–95              NaN
# 155                           NaN              NaN
#
#     balance_of_payments_manual_in_use external_debt_reporting_status  \
# 105                              BPM6                         Actual
# 155                              BPM6                            NaN
#
#           system_of_trade    government_accounting_concept  \
# 105  General trade system  Consolidated central government
# 155                   NaN                              NaN
#
#                 imf_data_dissemination_standard latest_population_census  \
# 105  Special Data Dissemination Standard (SDDS)          2020 (expected)
# 155                                         NaN                     2011
#
#                        latest_household_survey  \
# 105    Multiple Indicator Cluster Survey, 2015
# 155  Nauru Demographic and Health Survey, 2007
#
#     source_of_most_recent_income_and_expenditure_data  \
# 105    Expenditure survey/budget survey (ES/BS), 2017
# 155                                               NaN
#
#     vital_registration_complete latest_agricultural_census  \
# 105                         NaN                  2006-2007
# 155                         Yes                        NaN
#
#      latest_industrial_data  latest_trade_data  unnamed:_30  mean_age  \
# 105                  2013.0             2018.0          NaN        32
# 155                     NaN                NaN          NaN        51
#
#      total2016
# 105    3549011
# 155    8983025

# %% [markdown]
# Si evaluamos los valores únicos de las columnas que hacen referencia al país vemos que todas tienen el mismo número de elementos únicos. Si lo pensamos bien, estas columnas nos están dando la misma información.
#
# **¿Tiene sentido tenerlas todas en nuestro *DataFrame*?**
#
# En realidad no, por lo que podríamos proceder a eliminar todas menos una. Pero...🤔, ¿cuál eliminamos? En realidad no hay una fórmula para saber cuál eliminar. Pero nos podríamos quedar con la que más detalle nos aporte.

# %%
len(df.short_name.unique())
# Out:
# 198

# %%
len(df.table_name.unique())
# Out:
# 198

# %%
len(df.long_name.unique())
# Out:
# 198

# %%
len(df.country_code.unique())
# Out:
# 198

# %% [markdown]
# En este caso nos quedaremos con la variable `short_name`. Eliminemos el resto!
#
# Recordemos en Pandas tenemos el método `.drop()` que nos permite eliminar las columnas que le especifiquemos.

# %%
df.drop(["table_name", "long_name", "country_code"], axis = 1, inplace = True)

# %%
# chequeemos si se han eliminado las columnas

df.head(2)
# Out:
#   country_name m2016  f2016  index_   short_name 2-alpha_code   currency_unit  \
# 0        Aruba   NaN    1,8       0        Aruba           AW   Aruban florin
# 2  Afghanistan  53,2  4,635       2  Afghanistan           AF  Afghan afghani
#
#                                        special_notes  \
# 0                                                NaN
# 2  Fiscal year end: March 20; reporting period fo...
#
#                       region income_group wb-2_code  \
# 0  Latin America & Caribbean  High income        AW
# 2                 South Asia   Low income        AF
#
#   national_accounts_base_year  national_accounts_reference_year  \
# 0                        2000                               NaN
# 2                        2016                               NaN
#
#                  sna_price_valuation lending_category other_groups  \
# 0  Value added at basic prices (VAB)              NaN          NaN
# 2  Value added at basic prices (VAB)              IDA         HIPC
#
#                          system_of_national_accounts  \
# 0  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
#
#   alternative_conversion_factor  ppp_survey_year  \
# 0                           NaN              NaN
# 2                           NaN              NaN
#
#   balance_of_payments_manual_in_use external_debt_reporting_status  \
# 0                              BPM6                            NaN
# 2                              BPM6                         Actual
#
#         system_of_trade    government_accounting_concept  \
# 0  General trade system                              NaN
# 2  General trade system  Consolidated central government
#
#                      imf_data_dissemination_standard latest_population_census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 2  Enhanced General Data Dissemination System (e-...                     1979
#
#                latest_household_survey  \
# 0                                  NaN
# 2  Demographic and Health Survey, 2015
#
#   source_of_most_recent_income_and_expenditure_data  \
# 0                                               NaN
# 2        Integrated household survey (IHS), 2016/17
#
#   vital_registration_complete latest_agricultural_census  \
# 0                         Yes                        NaN
# 2                         NaN                        NaN
#
#    latest_industrial_data  latest_trade_data  unnamed:_30  mean_age  total2016
# 0                     NaN             2018.0          NaN        37     622308
# 2                     NaN             2018.0          NaN        80    3607857

# %% [markdown]
#  📌 Por otro lado, nos puede pasar que nos encontremos con alguna columna que todos sus valores sean nulos. Estas columnas no son reduntantes, pero son inútiles.
#
# Veamos como podemos calcular el porcentaje de nulos que tenemos en nuestras columnas:
#
# - Sacar el número de nulos que tenemos en nuestro *DataFrame* usando el método `isnull()`.
# - Sacar el número total de filas que tenemos en nuestro *DataFrame* usando el método `shape()`.

# %%
df.isnull().sum() * 100 / df.shape[0]
# Out:
# country_name                                           0.000000
# m2016                                                 11.111111
# f2016                                                  8.585859
# index_                                                 0.000000
# short_name                                             0.000000
# 2-alpha_code                                           1.010101
# currency_unit                                          0.000000
# special_notes                                         70.707071
# region                                                 0.000000
# income_group                                           0.000000
# wb-2_code                                              0.505051
# national_accounts_base_year                            3.030303
# national_accounts_reference_year                      64.141414
# sna_price_valuation                                    4.545455
# lending_category                                      33.838384
# other_groups                                          72.727273
# system_of_national_accounts                            3.535354
# alternative_conversion_factor                         78.787879
# ppp_survey_year                                      100.000000
# balance_of_payments_manual_in_use                      8.080808
# external_debt_reporting_status                        43.939394
# system_of_trade                                       20.202020
# government_accounting_concept                         26.767677
# imf_data_dissemination_standard                       13.636364
# latest_population_census                               1.010101
# latest_household_survey                               28.787879
# source_of_most_recent_income_and_expenditure_data     22.222222
# vital_registration_complete                           43.939394
# latest_agricultural_census                            40.404040
# latest_industrial_data                                31.818182
# latest_trade_data                                     11.111111
# unnamed:_30                                          100.000000
# mean_age                                               0.000000
# total2016                                              0.000000
# dtype: float64

# %% [markdown]
# Si nos fijamos tenemos 2 columnas que tienen el 100% de los valores como nulos (`ppp_survey_year` y `unnamed:_30`) por lo que podemos eliminarlas sin miedo.

# %%
df.drop(["ppp_survey_year", "unnamed:_30"], axis = 1, inplace = True)

# %%
# chequeemos si las hemos eliminado correctamente

df.head(2)
# Out:
#   country_name m2016  f2016  index_   short_name 2-alpha_code   currency_unit  \
# 0        Aruba   NaN    1,8       0        Aruba           AW   Aruban florin
# 2  Afghanistan  53,2  4,635       2  Afghanistan           AF  Afghan afghani
#
#                                        special_notes  \
# 0                                                NaN
# 2  Fiscal year end: March 20; reporting period fo...
#
#                       region income_group wb-2_code  \
# 0  Latin America & Caribbean  High income        AW
# 2                 South Asia   Low income        AF
#
#   national_accounts_base_year  national_accounts_reference_year  \
# 0                        2000                               NaN
# 2                        2016                               NaN
#
#                  sna_price_valuation lending_category other_groups  \
# 0  Value added at basic prices (VAB)              NaN          NaN
# 2  Value added at basic prices (VAB)              IDA         HIPC
#
#                          system_of_national_accounts  \
# 0  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
#
#   alternative_conversion_factor balance_of_payments_manual_in_use  \
# 0                           NaN                              BPM6
# 2                           NaN                              BPM6
#
#   external_debt_reporting_status       system_of_trade  \
# 0                            NaN  General trade system
# 2                         Actual  General trade system
#
#      government_accounting_concept  \
# 0                              NaN
# 2  Consolidated central government
#
#                      imf_data_dissemination_standard latest_population_census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 2  Enhanced General Data Dissemination System (e-...                     1979
#
#                latest_household_survey  \
# 0                                  NaN
# 2  Demographic and Health Survey, 2015
#
#   source_of_most_recent_income_and_expenditure_data  \
# 0                                               NaN
# 2        Integrated household survey (IHS), 2016/17
#
#   vital_registration_complete latest_agricultural_census  \
# 0                         Yes                        NaN
# 2                         NaN                        NaN
#
#    latest_industrial_data  latest_trade_data  mean_age  total2016
# 0                     NaN             2018.0        37     622308
# 2                     NaN             2018.0        80    3607857

# %% [markdown]
# Como hemos dicho, para saber cual es la relevancia de las columnas no hay ninguna fórmula. Pero recordemos algo:
#
# > La importancia de nuestras variables dependerá en gran parte de la pregunta que nos estemos haciendo.

# %% [markdown]
# ## Cambio del tipo de columna
#
# A veces puede ocurrir que al crear los datos o al importarlos estos tengan "asociado" un tipo de dato que no es correcto. Esto nos puede pasar mucho con las fechas (que lo ideal es que estén en formato datetime), con números (que deberían ser *integers* pero son *floats*  o incluso pueden llegar a ser *strings*).
#
# Veamos como podemos cambiar este tipo de datos.

# %%
# recordemos el dataframe

df.head(2)
# Out:
#   country_name m2016  f2016  index_   short_name 2-alpha_code   currency_unit  \
# 0        Aruba   NaN    1,8       0        Aruba           AW   Aruban florin
# 2  Afghanistan  53,2  4,635       2  Afghanistan           AF  Afghan afghani
#
#                                        special_notes  \
# 0                                                NaN
# 2  Fiscal year end: March 20; reporting period fo...
#
#                       region income_group wb-2_code  \
# 0  Latin America & Caribbean  High income        AW
# 2                 South Asia   Low income        AF
#
#   national_accounts_base_year  national_accounts_reference_year  \
# 0                        2000                               NaN
# 2                        2016                               NaN
#
#                  sna_price_valuation lending_category other_groups  \
# 0  Value added at basic prices (VAB)              NaN          NaN
# 2  Value added at basic prices (VAB)              IDA         HIPC
#
#                          system_of_national_accounts  \
# 0  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
#
#   alternative_conversion_factor balance_of_payments_manual_in_use  \
# 0                           NaN                              BPM6
# 2                           NaN                              BPM6
#
#   external_debt_reporting_status       system_of_trade  \
# 0                            NaN  General trade system
# 2                         Actual  General trade system
#
#      government_accounting_concept  \
# 0                              NaN
# 2  Consolidated central government
#
#                      imf_data_dissemination_standard latest_population_census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 2  Enhanced General Data Dissemination System (e-...                     1979
#
#                latest_household_survey  \
# 0                                  NaN
# 2  Demographic and Health Survey, 2015
#
#   source_of_most_recent_income_and_expenditure_data  \
# 0                                               NaN
# 2        Integrated household survey (IHS), 2016/17
#
#   vital_registration_complete latest_agricultural_census  \
# 0                         Yes                        NaN
# 2                         NaN                        NaN
#
#    latest_industrial_data  latest_trade_data  mean_age  total2016
# 0                     NaN             2018.0        37     622308
# 2                     NaN             2018.0        80    3607857

# %%
# y los tipos de datos que tenemos

df.dtypes
# Out:
# country_name                                          object
# m2016                                                 object
# f2016                                                 object
# index_                                                 int64
# short_name                                            object
# 2-alpha_code                                          object
# currency_unit                                         object
# special_notes                                         object
# region                                                object
# income_group                                          object
# wb-2_code                                             object
# national_accounts_base_year                           object
# national_accounts_reference_year                     float64
# sna_price_valuation                                   object
# lending_category                                      object
# other_groups                                          object
# system_of_national_accounts                           object
# alternative_conversion_factor                         object
# balance_of_payments_manual_in_use                     object
# external_debt_reporting_status                        object
# system_of_trade                                       object
# government_accounting_concept                         object
# imf_data_dissemination_standard                       object
# latest_population_census                              object
# latest_household_survey                               object
# source_of_most_recent_income_and_expenditure_data     object
# vital_registration_complete                           object
# latest_agricultural_census                            object
# latest_industrial_data                               float64
# latest_trade_data                                    float64
# mean_age                                               int64
# total2016                                              int64
# dtype: object

# %% [markdown]
# Identifiquemos posibles errores:
#
# - Las columnas de `national_accounts_reference_year`, `latest_industrial_data` y `latest_trade_data` están como *floats*  pero son años, por lo que deberíamos convertirlas a *integers*.
#
# - Las columnas `m2016`, `f2016` paracen como *strings*, pero deberían ser decimales. Esto está ocurriendo porque los decimales en vez de ser puntos son comas.

# %% [markdown]
# En Pandas tenemos el método `astype()`. El método se utiliza para convertir una columna de Pandas a un tipo de dato especificado.
#
# Su sintaxis es la siguiente:
#
# ```python
#     df[columna].astype(dtype, copy=True, errors='raise')
# ```
#
# Donde:
#
# - `dtype`: utilice un numpy.dtype tipo de Python o para convertir el objeto pandas completo en el mismo tipo.
#
# - `copy`: Devuelve una copia cuando `copy = True` (tenga mucho cuidado al establecer `copy = False` ya que los cambios en los valores pueden propagarse a otros objetos Pandas).
#
# - `errors`: controlar la generación de excepciones en datos no válidos para el tipo de datos proporcionado.
#
#     - `raise`: permitir que se generen excepciones.
#     - `ignore`: suprimir excepciones. En caso de error, devuelve el objeto original.

# %% [markdown]
# ### *Floats* que deberían ser *integers*

# %%
df["national_accounts_reference_year"] = df["national_accounts_reference_year"].astype('Int64', errors = "ignore")

# %%
df.sample(2)
# Out:
#    country_name m2016  f2016  index_ short_name 2-alpha_code  \
# 91    Indonesia  22,2  2,363     106  Indonesia           ID
# 22      Belarus   2,9  1,733      25    Belarus           BY
#
#         currency_unit                                      special_notes  \
# 91  Indonesian rupiah  Fiscal year end: March 31; reporting period fo...
# 22   Belarusian rubel  Data before 2015 were adjusted to reflect the ...
#
#                    region         income_group wb-2_code  \
# 91    East Asia & Pacific  Lower middle income        ID
# 22  Europe & Central Asia  Upper middle income        BY
#
#                           national_accounts_base_year  \
# 91                                               2010
# 22  Original chained constant price data are resca...
#
#     national_accounts_reference_year                sna_price_valuation  \
# 91                              <NA>  Value added at basic prices (VAB)
# 22                              2014  Value added at basic prices (VAB)
#
#    lending_category other_groups  \
# 91             IBRD          NaN
# 22             IBRD          NaN
#
#                           system_of_national_accounts  \
# 91  Country uses the 2008 System of National Accou...
# 22  Country uses the 2008 System of National Accou...
#
#    alternative_conversion_factor balance_of_payments_manual_in_use  \
# 91                           NaN                              BPM6
# 22                       1990–95                              BPM6
#
#    external_debt_reporting_status       system_of_trade  \
# 91                         Actual  General trade system
# 22                         Actual  General trade system
#
#       government_accounting_concept  \
# 91  Consolidated central government
# 22  Consolidated central government
#
#                imf_data_dissemination_standard latest_population_census  \
# 91  Special Data Dissemination Standard (SDDS)          2020 (expected)
# 22  Special Data Dissemination Standard (SDDS)                     2019
#
#                               latest_household_survey  \
# 91  Demographic and Health Survey, 2017; Indonesia...
# 22            Multiple Indicator Cluster Survey, 2019
#
#    source_of_most_recent_income_and_expenditure_data  \
# 91           Integrated household survey (IHS), 2017
# 22           Integrated household survey (IHS), 2017
#
#    vital_registration_complete latest_agricultural_census  \
# 91                         NaN                       2013
# 22                         Yes                        NaN
#
#     latest_industrial_data  latest_trade_data  mean_age  total2016
# 91                  2013.0             2018.0        56    7891878
# 22                  2014.0             2018.0        80    4104178

# %%
# si chequeamos ahora el tipo de los valores de la columna ya no serán floats, ahora son integers! 

df["national_accounts_reference_year"].dtypes
# Out:
# Int64Dtype()

# %% [markdown]
# 📌 Si nos fijamos ahora los valores NaN son un poco diferentes:
#
# ```python
# df["national_accounts_reference_year"][0]
#
# # output:
# <NA>
# ```
#
# La diferencia con los NaN que estabamos acostumbradas a ver es que estos son los valores nulos de Pandas. Pero podremos operar con ellos de la misma forma.

# %%
# no hace falta que lo hagamos columna a columna, lo podemos hacer con varias columnas a la vez

df[['latest_industrial_data', 'latest_trade_data']] = df[['latest_industrial_data', 'latest_trade_data']].astype("Int64", errors = "ignore")

# %%
# chequeemos si se ha cambiado el tipo de la columna latest_industrial_data

df["latest_industrial_data"].dtypes
# Out:
# Int64Dtype()

# %%
# y que ha pasado con latest_trade_data

df['latest_trade_data'].dtypes
# Out:
# Int64Dtype()

# %% [markdown]
# ## *Strings* que deberían ser decimales

# %%
df.head(2)
# Out:
#   country_name m2016  f2016  index_   short_name 2-alpha_code   currency_unit  \
# 0        Aruba   NaN    1,8       0        Aruba           AW   Aruban florin
# 2  Afghanistan  53,2  4,635       2  Afghanistan           AF  Afghan afghani
#
#                                        special_notes  \
# 0                                                NaN
# 2  Fiscal year end: March 20; reporting period fo...
#
#                       region income_group wb-2_code  \
# 0  Latin America & Caribbean  High income        AW
# 2                 South Asia   Low income        AF
#
#   national_accounts_base_year  national_accounts_reference_year  \
# 0                        2000                              <NA>
# 2                        2016                              <NA>
#
#                  sna_price_valuation lending_category other_groups  \
# 0  Value added at basic prices (VAB)              NaN          NaN
# 2  Value added at basic prices (VAB)              IDA         HIPC
#
#                          system_of_national_accounts  \
# 0  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
#
#   alternative_conversion_factor balance_of_payments_manual_in_use  \
# 0                           NaN                              BPM6
# 2                           NaN                              BPM6
#
#   external_debt_reporting_status       system_of_trade  \
# 0                            NaN  General trade system
# 2                         Actual  General trade system
#
#      government_accounting_concept  \
# 0                              NaN
# 2  Consolidated central government
#
#                      imf_data_dissemination_standard latest_population_census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 2  Enhanced General Data Dissemination System (e-...                     1979
#
#                latest_household_survey  \
# 0                                  NaN
# 2  Demographic and Health Survey, 2015
#
#   source_of_most_recent_income_and_expenditure_data  \
# 0                                               NaN
# 2        Integrated household survey (IHS), 2016/17
#
#   vital_registration_complete latest_agricultural_census  \
# 0                         Yes                        NaN
# 2                         NaN                        NaN
#
#    latest_industrial_data  latest_trade_data  mean_age  total2016
# 0                    <NA>               2018        37     622308
# 2                    <NA>               2018        80    3607857

# %%
df[["m2016", 'f2016']] = df[["m2016", 'f2016']].replace(r',', ".", regex=True)

# %%
df.head(2)
# Out:
#   country_name m2016  f2016  index_   short_name 2-alpha_code   currency_unit  \
# 0        Aruba   NaN    1.8       0        Aruba           AW   Aruban florin
# 2  Afghanistan  53.2  4.635       2  Afghanistan           AF  Afghan afghani
#
#                                        special_notes  \
# 0                                                NaN
# 2  Fiscal year end: March 20; reporting period fo...
#
#                       region income_group wb-2_code  \
# 0  Latin America & Caribbean  High income        AW
# 2                 South Asia   Low income        AF
#
#   national_accounts_base_year  national_accounts_reference_year  \
# 0                        2000                              <NA>
# 2                        2016                              <NA>
#
#                  sna_price_valuation lending_category other_groups  \
# 0  Value added at basic prices (VAB)              NaN          NaN
# 2  Value added at basic prices (VAB)              IDA         HIPC
#
#                          system_of_national_accounts  \
# 0  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
#
#   alternative_conversion_factor balance_of_payments_manual_in_use  \
# 0                           NaN                              BPM6
# 2                           NaN                              BPM6
#
#   external_debt_reporting_status       system_of_trade  \
# 0                            NaN  General trade system
# 2                         Actual  General trade system
#
#      government_accounting_concept  \
# 0                              NaN
# 2  Consolidated central government
#
#                      imf_data_dissemination_standard latest_population_census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 2  Enhanced General Data Dissemination System (e-...                     1979
#
#                latest_household_survey  \
# 0                                  NaN
# 2  Demographic and Health Survey, 2015
#
#   source_of_most_recent_income_and_expenditure_data  \
# 0                                               NaN
# 2        Integrated household survey (IHS), 2016/17
#
#   vital_registration_complete latest_agricultural_census  \
# 0                         Yes                        NaN
# 2                         NaN                        NaN
#
#    latest_industrial_data  latest_trade_data  mean_age  total2016
# 0                    <NA>               2018        37     622308
# 2                    <NA>               2018        80    3607857

# %% [markdown]
# Ahora siguen siendo strings, los cambiamos a float:

# %%
df[['m2016','f2016']].dtypes
# Out:
# m2016    object
# f2016    object
# dtype: object

# %%
df = df.astype({'m2016': 'float64', 'f2016': 'float64'}, copy=True, errors='raise')

# %%
df[['m2016','f2016']].dtypes
# Out:
# m2016    float64
# f2016    float64
# dtype: object

# %% [markdown]
# ## Ordenar columnas
#
# En este sentido nos referimos a dos cosas:
#
# - Cambiar una columna al índice
# - Cambiar el orden de nuestras columnas

# %% [markdown]
# ### Cambiar una columna al índice:

# %% [markdown]
# Por un lado tenemos la columna `index`, que es una columna con valores únicos que nos va a ayudar a indentificar mejor las entradas en nuestro *DataFrame*. En este caso, cuando tenemos este tipo de columnas lo ideal es pasar esta columna al índice usando el método `set_index()`.

# %%
df.head(2)
# Out:
#   country_name  m2016  f2016  index_   short_name 2-alpha_code  \
# 0        Aruba    NaN  1.800       0        Aruba           AW
# 2  Afghanistan   53.2  4.635       2  Afghanistan           AF
#
#     currency_unit                                      special_notes  \
# 0   Aruban florin                                                NaN
# 2  Afghan afghani  Fiscal year end: March 20; reporting period fo...
#
#                       region income_group wb-2_code  \
# 0  Latin America & Caribbean  High income        AW
# 2                 South Asia   Low income        AF
#
#   national_accounts_base_year  national_accounts_reference_year  \
# 0                        2000                              <NA>
# 2                        2016                              <NA>
#
#                  sna_price_valuation lending_category other_groups  \
# 0  Value added at basic prices (VAB)              NaN          NaN
# 2  Value added at basic prices (VAB)              IDA         HIPC
#
#                          system_of_national_accounts  \
# 0  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
#
#   alternative_conversion_factor balance_of_payments_manual_in_use  \
# 0                           NaN                              BPM6
# 2                           NaN                              BPM6
#
#   external_debt_reporting_status       system_of_trade  \
# 0                            NaN  General trade system
# 2                         Actual  General trade system
#
#      government_accounting_concept  \
# 0                              NaN
# 2  Consolidated central government
#
#                      imf_data_dissemination_standard latest_population_census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 2  Enhanced General Data Dissemination System (e-...                     1979
#
#                latest_household_survey  \
# 0                                  NaN
# 2  Demographic and Health Survey, 2015
#
#   source_of_most_recent_income_and_expenditure_data  \
# 0                                               NaN
# 2        Integrated household survey (IHS), 2016/17
#
#   vital_registration_complete latest_agricultural_census  \
# 0                         Yes                        NaN
# 2                         NaN                        NaN
#
#    latest_industrial_data  latest_trade_data  mean_age  total2016
# 0                    <NA>               2018        37     622308
# 2                    <NA>               2018        80    3607857

# %%
df.set_index("index_", inplace = True)

# %%
# si chequeamos ahora nuestro dataset ya tendremos la columna de "index" como índice. 

df.head(2)
# Out:
#        country_name  m2016  f2016   short_name 2-alpha_code   currency_unit  \
# index_
# 0             Aruba    NaN  1.800        Aruba           AW   Aruban florin
# 2       Afghanistan   53.2  4.635  Afghanistan           AF  Afghan afghani
#
#                                             special_notes  \
# index_
# 0                                                     NaN
# 2       Fiscal year end: March 20; reporting period fo...
#
#                            region income_group wb-2_code  \
# index_
# 0       Latin America & Caribbean  High income        AW
# 2                      South Asia   Low income        AF
#
#        national_accounts_base_year  national_accounts_reference_year  \
# index_
# 0                             2000                              <NA>
# 2                             2016                              <NA>
#
#                       sna_price_valuation lending_category other_groups  \
# index_
# 0       Value added at basic prices (VAB)              NaN          NaN
# 2       Value added at basic prices (VAB)              IDA         HIPC
#
#                               system_of_national_accounts  \
# index_
# 0       Country uses the 1993 System of National Accou...
# 2       Country uses the 1993 System of National Accou...
#
#        alternative_conversion_factor balance_of_payments_manual_in_use  \
# index_
# 0                                NaN                              BPM6
# 2                                NaN                              BPM6
#
#        external_debt_reporting_status       system_of_trade  \
# index_
# 0                                 NaN  General trade system
# 2                              Actual  General trade system
#
#           government_accounting_concept  \
# index_
# 0                                   NaN
# 2       Consolidated central government
#
#                           imf_data_dissemination_standard  \
# index_
# 0       Enhanced General Data Dissemination System (e-...
# 2       Enhanced General Data Dissemination System (e-...
#
#        latest_population_census              latest_household_survey  \
# index_
# 0               2020 (expected)                                  NaN
# 2                          1979  Demographic and Health Survey, 2015
#
#        source_of_most_recent_income_and_expenditure_data  \
# index_
# 0                                                    NaN
# 2             Integrated household survey (IHS), 2016/17
#
#        vital_registration_complete latest_agricultural_census  \
# index_
# 0                              Yes                        NaN
# 2                              NaN                        NaN
#
#         latest_industrial_data  latest_trade_data  mean_age  total2016
# index_
# 0                         <NA>               2018        37     622308
# 2                         <NA>               2018        80    3607857

# %% [markdown]
# ## Cambiar el orden de nuestras columnas
#
# Lo podemos hacer utilizando el método `.reindex()` de Pandas.
#
# ```python
#     pd.MiDataFrame.reindex(columns=nombre_columnas)
# ```
# Donde:
#
# - `columns`: es una lista con el nombre de las columnas reorganizadas.

# %%
# primero convierto el nombre de mis columnas en una lista: 

lista_columnas = df.columns.to_list()
print(lista_columnas)
# Out:
# ['country_name', 'm2016', 'f2016', 'short_name', '2-alpha_code', 'currency_unit', 'special_notes', 'region', 'income_group', 'wb-2_code', 'national_accounts_base_year', 'national_accounts_reference_year', 'sna_price_valuation', 'lending_category', 'other_groups', 'system_of_national_accounts', 'alternative_conversion_factor', 'balance_of_payments_manual_in_use', 'external_debt_reporting_status', 'system_of_trade', 'government_accounting_concept', 'imf_data_dissemination_standard', 'latest_population_census', 'latest_household_survey', 'source_of_most_recent_income_and_expenditure_data', 'vital_registration_complete', 'latest_agricultural_census', 'latest_industrial_data', 'latest_trade_data', 'mean_age', 'total2016']

# %%
# definimos el nuevo orden de nuestras columnas

nuevo_orden =['country_name', 'short_name', '2-alpha_code', 'currency_unit', 'special_notes', 'region', 
              'income_group', 'wb-2_code', 'national_accounts_base_year', 'national_accounts_reference_year',
              'sna_price_valuation', 'lending_category', 'other_groups', 'system_of_national_accounts',
              'alternative_conversion_factor', 'balance_of_payments_manual_in_use', 'external_debt_reporting_status', 
              'system_of_trade', 'government_accounting_concept', 'imf_data_dissemination_standard', 'latest_population_census',
              'latest_household_survey', 'source_of_most_recent_income_and_expenditure_data', 'vital_registration_complete',
              'latest_agricultural_census', 'latest_industrial_data', 'latest_trade_data', 'mean_age',
              'total2016', 'm2016', 'f2016']

# %%
# aplicamos el método reindex

df2 = df.reindex(columns=nuevo_orden)

# %%
# chequeamos si se ha cambiado el orden

df2.head(2)
# Out:
#        country_name   short_name 2-alpha_code   currency_unit  \
# index_
# 0             Aruba        Aruba           AW   Aruban florin
# 2       Afghanistan  Afghanistan           AF  Afghan afghani
#
#                                             special_notes  \
# index_
# 0                                                     NaN
# 2       Fiscal year end: March 20; reporting period fo...
#
#                            region income_group wb-2_code  \
# index_
# 0       Latin America & Caribbean  High income        AW
# 2                      South Asia   Low income        AF
#
#        national_accounts_base_year  national_accounts_reference_year  \
# index_
# 0                             2000                              <NA>
# 2                             2016                              <NA>
#
#                       sna_price_valuation lending_category other_groups  \
# index_
# 0       Value added at basic prices (VAB)              NaN          NaN
# 2       Value added at basic prices (VAB)              IDA         HIPC
#
#                               system_of_national_accounts  \
# index_
# 0       Country uses the 1993 System of National Accou...
# 2       Country uses the 1993 System of National Accou...
#
#        alternative_conversion_factor balance_of_payments_manual_in_use  \
# index_
# 0                                NaN                              BPM6
# 2                                NaN                              BPM6
#
#        external_debt_reporting_status       system_of_trade  \
# index_
# 0                                 NaN  General trade system
# 2                              Actual  General trade system
#
#           government_accounting_concept  \
# index_
# 0                                   NaN
# 2       Consolidated central government
#
#                           imf_data_dissemination_standard  \
# index_
# 0       Enhanced General Data Dissemination System (e-...
# 2       Enhanced General Data Dissemination System (e-...
#
#        latest_population_census              latest_household_survey  \
# index_
# 0               2020 (expected)                                  NaN
# 2                          1979  Demographic and Health Survey, 2015
#
#        source_of_most_recent_income_and_expenditure_data  \
# index_
# 0                                                    NaN
# 2             Integrated household survey (IHS), 2016/17
#
#        vital_registration_complete latest_agricultural_census  \
# index_
# 0                              Yes                        NaN
# 2                              NaN                        NaN
#
#         latest_industrial_data  latest_trade_data  mean_age  total2016  m2016  \
# index_
# 0                         <NA>               2018        37     622308    NaN
# 2                         <NA>               2018        80    3607857   53.2
#
#         f2016
# index_
# 0       1.800
# 2       4.635

# %% [markdown]
# **Antes de cerrar el jupyter guardemos los cambios hechos para seguir trabajando con este jupyter en las siguientes lecciones:**

# %%
df.to_csv('files/WDICountry_limpio.csv')

# %% [markdown]
# ## EJERCICIOS
#
# En los ejercicios de las clases invertidas de limpieza vamos a trabajar con el dataset `south.csv` que tenéis en el apartado Datos - Limpieza en el Gitbook.
#
# - 1️⃣ Haz un pequeño anális exploratorio del dataset.
#
#     - ¿Cuántas filas y columnas tenemos?
#     - ¿Cuales son los principales estadísticos de nuestras columnas numéricas?
#     - ¿Qué información nos da este dataset?
#
#
# - 2️⃣ Pon el nombre de las columnas todo en minúscula y quita los espacios. Usa una dict comprehension.
#
# - 3️⃣ Chequea si hay duplicados en el DataFrame. En caso de que lo haya, elimina todos los duplicados en función de la fecha.
#
# - 4️⃣ Saca el porcentaje de valores nulos que tenemos por columna. ¿Hay alguna variable que tenga más de un 90% de valores nulos?
#
#     - Si es así, ¿Qué harías con esa columna?
#
# - 5️⃣ En general en este DataFrame los tipos están bien asignados. Sin embargo hay una columna a la que podríamos cambiarle el tipo del dato. ¿Qué columna es? Cuando la identifiques cámbiala.
#
# - 6️⃣ Cambia el orden de las columnas y pon las columnas de 'region', 'state', 'station', 'station_code', 'latitude', 'longitude' en primer lugar.

# %%
south = pd.read_csv('files/south.csv', index_col=0)

# %%
south.head(2)
# Out:
#              Data   Hora  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# index
# 0      2000-09-22  00:00                               NaN
# 1      2000-09-22  01:00                               NaN
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# index
# 0                                                    NaN
# 1                                                    NaN
#
#        PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# index
# 0                                                  NaN
# 1                                                  NaN
#
#        PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# index
# 0                                                   NaN
# 1                                                   NaN
#
#        RADIACAO GLOBAL (Kj/m²)  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# index
# 0                          NaN                                           NaN
# 1                          NaN                                           NaN
#
#        TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# index
# 0                                       NaN
# 1                                       NaN
#
#        TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# index
# 0                                             NaN
# 1                                             NaN
#
#        TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# index
# 0                                             NaN
# 1                                             NaN
#
#        TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# index
# 0                                                   NaN
# 1                                                   NaN
#
#        TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# index
# 0                                                   NaN
# 1                                                   NaN
#
#        UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# index
# 0                                           NaN
# 1                                           NaN
#
#        UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# index
# 0                                           NaN
# 1                                           NaN
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  \
# index
# 0                                      NaN
# 1                                      NaN
#
#        VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# index
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
#
#        VENTO, VELOCIDADE HORARIA (m/s) region state       station  \
# index
# 0                                  NaN      S    RS  PORTO ALEGRE
# 1                                  NaN      S   NaN  PORTO ALEGRE
#
#       station_code  latitude  longitude  height
# index
# 0             A801    -30.05 -51.166667   46.97
# 1             A801    -30.05 -51.166667   46.97

# %%
south.shape
# Out:
# (10023, 26)

# %%
south.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10023 entries, 0 to 707
# Data columns (total 26 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Data                                                   10023 non-null  object
#  1   Hora                                                   10023 non-null  object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       9040 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  9037 non-null   float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8943 non-null   float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8943 non-null   float64
#  6   RADIACAO GLOBAL (Kj/m²)                                5267 non-null   float64
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           9042 non-null   float64
#  8   TEMPERATURA DO PONTO DE ORVALHO (°C)                   9042 non-null   float64
#  9   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)             8943 non-null   float64
#  10  TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)             8943 non-null   float64
#  11  TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)       8943 non-null   float64
#  12  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)       8943 non-null   float64
#  13  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               8943 non-null   float64
#  14  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               8943 non-null   float64
#  15  UMIDADE RELATIVA DO AR, HORARIA (%)                    9042 non-null   float64
#  16  VENTO, DIREÇÃO HORARIA (gr) (° (gr))                   8951 non-null   float64
#  17  VENTO, RAJADA MAXIMA (m/s)                             8941 non-null   float64
#  18  VENTO, VELOCIDADE HORARIA (m/s)                        9039 non-null   float64
#  19  region                                                 6871 non-null   object
#  20  state                                                  6837 non-null   object
#  21  station                                                6830 non-null   object
#  22  station_code                                           10023 non-null  object
#  23  latitude                                               10023 non-null  float64
#  24  longitude                                              10023 non-null  float64
#  25  height                                                 10023 non-null  float64
# dtypes: float64(20), object(6)
# memory usage: 2.1+ MB

# %%
south.describe(include='all').T
# Out:
#                                                       count unique  \
# Data                                                  10023    314
# Hora                                                  10023     24
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                     9040.0    NaN
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARI...   9037.0    NaN
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)      8943.0    NaN
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)     8943.0    NaN
# RADIACAO GLOBAL (Kj/m²)                              5267.0    NaN
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)         9042.0    NaN
# TEMPERATURA DO PONTO DE ORVALHO (°C)                 9042.0    NaN
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)           8943.0    NaN
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)           8943.0    NaN
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)     8943.0    NaN
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)     8943.0    NaN
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)             8943.0    NaN
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)             8943.0    NaN
# UMIDADE RELATIVA DO AR, HORARIA (%)                  9042.0    NaN
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                 8951.0    NaN
# VENTO, RAJADA MAXIMA (m/s)                           8941.0    NaN
# VENTO, VELOCIDADE HORARIA (m/s)                      9039.0    NaN
# region                                                 6871      1
# state                                                  6837      1
# station                                                6830      5
# station_code                                          10023      5
# latitude                                            10023.0    NaN
# longitude                                           10023.0    NaN
# height                                              10023.0    NaN
#
#                                                              top  freq  \
# Data                                                  2001-12-24    98
# Hora                                                       13:00   420
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                             NaN   NaN
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARI...           NaN   NaN
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)              NaN   NaN
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)             NaN   NaN
# RADIACAO GLOBAL (Kj/m²)                                      NaN   NaN
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)                 NaN   NaN
# TEMPERATURA DO PONTO DE ORVALHO (°C)                         NaN   NaN
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                   NaN   NaN
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                   NaN   NaN
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)             NaN   NaN
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)             NaN   NaN
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                     NaN   NaN
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                     NaN   NaN
# UMIDADE RELATIVA DO AR, HORARIA (%)                          NaN   NaN
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                         NaN   NaN
# VENTO, RAJADA MAXIMA (m/s)                                   NaN   NaN
# VENTO, VELOCIDADE HORARIA (m/s)                              NaN   NaN
# region                                                         S  6871
# state                                                         RS  6837
# station                                             PORTO ALEGRE  4516
# station_code                                                A801  6433
# latitude                                                     NaN   NaN
# longitude                                                    NaN   NaN
# height                                                       NaN   NaN
#
#                                                            mean          std  \
# Data                                                        NaN          NaN
# Hora                                                        NaN          NaN
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       0.158341     1.154292
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARI...  1000.779119    17.094535
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)     1000.951124    17.134889
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)    1000.433646    17.131324
# RADIACAO GLOBAL (Kj/m²)                             1434.053351  1202.238064
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           22.02129     4.634252
# TEMPERATURA DO PONTO DE ORVALHO (°C)                  16.752853     3.759026
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)            22.569406     4.757237
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)            21.545701     4.500276
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)       17.28231     3.675633
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)       16.25497     3.901331
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)              76.813597    14.973802
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)              71.185285    17.017259
# UMIDADE RELATIVA DO AR, HORARIA (%)                   74.145764    16.101931
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                 151.232265    81.674579
# VENTO, RAJADA MAXIMA (m/s)                             5.347489     2.756823
# VENTO, VELOCIDADE HORARIA (m/s)                        2.224793     1.506177
# region                                                      NaN          NaN
# state                                                       NaN          NaN
# station                                                     NaN          NaN
# station_code                                                NaN          NaN
# latitude                                             -30.173873     0.896698
# longitude                                            -52.087242     1.467861
# height                                                89.304461   116.249565
#
#                                                           min     25%  \
# Data                                                      NaN     NaN
# Hora                                                      NaN     NaN
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          0.0     0.0
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARI...      946.0  1000.7
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)         946.5  1000.9
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)        945.9  1000.2
# RADIACAO GLOBAL (Kj/m²)                                   0.0   324.0
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              7.1    18.8
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     -0.4    14.4
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                7.6    19.3
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                6.9    18.5
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          1.3    14.9
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         -2.3    13.8
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 27.0    67.0
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 21.0    59.0
# UMIDADE RELATIVA DO AR, HORARIA (%)                      23.0    63.0
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                      1.0    98.0
# VENTO, RAJADA MAXIMA (m/s)                                0.0     3.3
# VENTO, VELOCIDADE HORARIA (m/s)                           0.0     1.1
# region                                                    NaN     NaN
# state                                                     NaN     NaN
# station                                                   NaN     NaN
# station_code                                              NaN     NaN
# latitude                                           -32.033333  -30.05
# longitude                                          -55.612778   -52.1
# height                                                   2.46   46.97
#
#                                                           50%        75%  \
# Data                                                      NaN        NaN
# Hora                                                      NaN        NaN
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          0.0        0.0
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARI...     1006.6     1010.4
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        1006.8     1010.6
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       1006.3     1010.1
# RADIACAO GLOBAL (Kj/m²)                                1209.0     2422.5
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)             21.8     24.975
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     17.2       19.6
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               22.3       25.6
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               21.4       24.4
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         17.7       20.1
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         16.8       19.2
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 80.0       89.0
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 74.0       86.0
# UMIDADE RELATIVA DO AR, HORARIA (%)                      78.0       88.0
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                    124.0      194.0
# VENTO, RAJADA MAXIMA (m/s)                                5.1        7.0
# VENTO, VELOCIDADE HORARIA (m/s)                           2.0        3.0
# region                                                    NaN        NaN
# state                                                     NaN        NaN
# station                                                   NaN        NaN
# station_code                                              NaN        NaN
# latitude                                               -30.05     -30.05
# longitude                                          -51.166667 -51.166667
# height                                                  46.97      46.97
#
#                                                           max
# Data                                                      NaN
# Hora                                                      NaN
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                         38.6
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARI...     1026.8
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        1026.9
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       1026.7
# RADIACAO GLOBAL (Kj/m²)                                4257.0
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)             35.8
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     24.3
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               36.2
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               35.2
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         24.9
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         23.6
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 99.0
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 99.0
# UMIDADE RELATIVA DO AR, HORARIA (%)                      99.0
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                    360.0
# VENTO, RAJADA MAXIMA (m/s)                               23.7
# VENTO, VELOCIDADE HORARIA (m/s)                          13.3
# region                                                    NaN
# state                                                     NaN
# station                                                   NaN
# station_code                                              NaN
# latitude                                           -27.854167
# longitude                                          -51.166667
# height                                                  490.0

# %%
nuevas_col = {col:col.strip().lower().replace(' ', '_') for col in south.columns}

# %%
south.rename(columns=nuevas_col, inplace =True)

# %%
south.head(2)
# Out:
#              data   hora  precipitação_total,_horário_(mm)  \
# index
# 0      2000-09-22  00:00                               NaN
# 1      2000-09-22  01:00                               NaN
#
#        pressao_atmosferica_ao_nivel_da_estacao,_horaria_(mb)  \
# index
# 0                                                    NaN
# 1                                                    NaN
#
#        pressão_atmosferica_max.na_hora_ant._(aut)_(mb)  \
# index
# 0                                                  NaN
# 1                                                  NaN
#
#        pressão_atmosferica_min._na_hora_ant._(aut)_(mb)  \
# index
# 0                                                   NaN
# 1                                                   NaN
#
#        radiacao_global_(kj/m²)  temperatura_do_ar_-_bulbo_seco,_horaria_(°c)  \
# index
# 0                          NaN                                           NaN
# 1                          NaN                                           NaN
#
#        temperatura_do_ponto_de_orvalho_(°c)  \
# index
# 0                                       NaN
# 1                                       NaN
#
#        temperatura_máxima_na_hora_ant._(aut)_(°c)  \
# index
# 0                                             NaN
# 1                                             NaN
#
#        temperatura_mínima_na_hora_ant._(aut)_(°c)  \
# index
# 0                                             NaN
# 1                                             NaN
#
#        temperatura_orvalho_max._na_hora_ant._(aut)_(°c)  \
# index
# 0                                                   NaN
# 1                                                   NaN
#
#        temperatura_orvalho_min._na_hora_ant._(aut)_(°c)  \
# index
# 0                                                   NaN
# 1                                                   NaN
#
#        umidade_rel._max._na_hora_ant._(aut)_(%)  \
# index
# 0                                           NaN
# 1                                           NaN
#
#        umidade_rel._min._na_hora_ant._(aut)_(%)  \
# index
# 0                                           NaN
# 1                                           NaN
#
#        umidade_relativa_do_ar,_horaria_(%)  \
# index
# 0                                      NaN
# 1                                      NaN
#
#        vento,_direção_horaria_(gr)_(°_(gr))  vento,_rajada_maxima_(m/s)  \
# index
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
#
#        vento,_velocidade_horaria_(m/s) region state       station  \
# index
# 0                                  NaN      S    RS  PORTO ALEGRE
# 1                                  NaN      S   NaN  PORTO ALEGRE
#
#       station_code  latitude  longitude  height
# index
# 0             A801    -30.05 -51.166667   46.97
# 1             A801    -30.05 -51.166667   46.97

# %%
south.duplicated().sum()
# Out:
# 23

# %%
south.duplicated(['data']).sum()
# Out:
# 9709

# %%
south.drop_duplicates(subset =['data'], inplace = True)

# %%
south.isnull().sum() / south.shape[0] * 100
# Out:
# data                                                      0.000000
# hora                                                      0.000000
# precipitação_total,_horário_(mm)                         12.420382
# pressao_atmosferica_ao_nivel_da_estacao,_horaria_(mb)    12.420382
# pressão_atmosferica_max.na_hora_ant._(aut)_(mb)          13.694268
# pressão_atmosferica_min._na_hora_ant._(aut)_(mb)         13.694268
# radiacao_global_(kj/m²)                                  99.363057
# temperatura_do_ar_-_bulbo_seco,_horaria_(°c)             12.420382
# temperatura_do_ponto_de_orvalho_(°c)                     12.420382
# temperatura_máxima_na_hora_ant._(aut)_(°c)               13.694268
# temperatura_mínima_na_hora_ant._(aut)_(°c)               13.694268
# temperatura_orvalho_max._na_hora_ant._(aut)_(°c)         13.694268
# temperatura_orvalho_min._na_hora_ant._(aut)_(°c)         13.694268
# umidade_rel._max._na_hora_ant._(aut)_(%)                 13.694268
# umidade_rel._min._na_hora_ant._(aut)_(%)                 13.694268
# umidade_relativa_do_ar,_horaria_(%)                      12.420382
# vento,_direção_horaria_(gr)_(°_(gr))                     13.694268
# vento,_rajada_maxima_(m/s)                               13.694268
# vento,_velocidade_horaria_(m/s)                          12.420382
# region                                                   31.847134
# state                                                    28.980892
# station                                                  27.388535
# station_code                                              0.000000
# latitude                                                  0.000000
# longitude                                                 0.000000
# height                                                    0.000000
# dtype: float64

# %%
south.drop('radiacao_global_(kj/m²)', axis =1, inplace = True)

# %%
south.dtypes
# Out:
# data                                                      object
# hora                                                      object
# precipitação_total,_horário_(mm)                         float64
# pressao_atmosferica_ao_nivel_da_estacao,_horaria_(mb)    float64
# pressão_atmosferica_max.na_hora_ant._(aut)_(mb)          float64
# pressão_atmosferica_min._na_hora_ant._(aut)_(mb)         float64
# temperatura_do_ar_-_bulbo_seco,_horaria_(°c)             float64
# temperatura_do_ponto_de_orvalho_(°c)                     float64
# temperatura_máxima_na_hora_ant._(aut)_(°c)               float64
# temperatura_mínima_na_hora_ant._(aut)_(°c)               float64
# temperatura_orvalho_max._na_hora_ant._(aut)_(°c)         float64
# temperatura_orvalho_min._na_hora_ant._(aut)_(°c)         float64
# umidade_rel._max._na_hora_ant._(aut)_(%)                 float64
# umidade_rel._min._na_hora_ant._(aut)_(%)                 float64
# umidade_relativa_do_ar,_horaria_(%)                      float64
# vento,_direção_horaria_(gr)_(°_(gr))                     float64
# vento,_rajada_maxima_(m/s)                               float64
# vento,_velocidade_horaria_(m/s)                          float64
# region                                                    object
# state                                                     object
# station                                                   object
# station_code                                              object
# latitude                                                 float64
# longitude                                                float64
# height                                                   float64
# dtype: object

# %%
south.columns.to_list()
# Out:
# ['data',
#  'hora',
#  'precipitação_total,_horário_(mm)',
#  'pressao_atmosferica_ao_nivel_da_estacao,_horaria_(mb)',
#  'pressão_atmosferica_max.na_hora_ant._(aut)_(mb)',
#  'pressão_atmosferica_min._na_hora_ant._(aut)_(mb)',
#  'temperatura_do_ar_-_bulbo_seco,_horaria_(°c)',
#  'temperatura_do_ponto_de_orvalho_(°c)',
#  'temperatura_máxima_na_hora_ant._(aut)_(°c)',
#  'temperatura_mínima_na_hora_ant._(aut)_(°c)',
#  'temperatura_orvalho_max._na_hora_ant._(aut)_(°c)',
#  'temperatura_orvalho_min._na_hora_ant._(aut)_(°c)',
#  'umidade_rel._max._na_hora_ant._(aut)_(%)',
#  'umidade_rel._min._na_hora_ant._(aut)_(%)',
#  'umidade_relativa_do_ar,_horaria_(%)',
#  'vento,_direção_horaria_(gr)_(°_(gr))',
#  'vento,_rajada_maxima_(m/s)',
#  'vento,_velocidade_horaria_(m/s)',
#  'region',
#  'state',
#  'station',
#  'station_code',
#  'latitude',
#  'longitude',
#  'height']

# %%
orden_col = {'region', 'state', 'station', 'station_code', 'latitude', 'longitude', 'height', 'data',
 'hora','precipitação_total,_horário_(mm)',
 'pressao_atmosferica_ao_nivel_da_estacao,_horaria_(mb)',
 'pressão_atmosferica_max.na_hora_ant._(aut)_(mb)',
 'pressão_atmosferica_min._na_hora_ant._(aut)_(mb)',
 'temperatura_do_ar_-_bulbo_seco,_horaria_(°c)',
 'temperatura_do_ponto_de_orvalho_(°c)',
 'temperatura_máxima_na_hora_ant._(aut)_(°c)',
 'temperatura_mínima_na_hora_ant._(aut)_(°c)',
 'temperatura_orvalho_max._na_hora_ant._(aut)_(°c)',
 'temperatura_orvalho_min._na_hora_ant._(aut)_(°c)',
 'umidade_rel._max._na_hora_ant._(aut)_(%)',
 'umidade_rel._min._na_hora_ant._(aut)_(%)',
 'umidade_relativa_do_ar,_horaria_(%)',
 'vento,_direção_horaria_(gr)_(°_(gr))',
 'vento,_rajada_maxima_(m/s)',
 'vento,_velocidade_horaria_(m/s)'}

# %%
south2 = south.reindex(columns = orden_col)

# %%
south2.head(2)
# Out:
#        temperatura_orvalho_min._na_hora_ant._(aut)_(°c)  \
# index
# 0                                                   NaN
# 24                                                  8.9
#
#        vento,_rajada_maxima_(m/s)       station  \
# index
# 0                             NaN  PORTO ALEGRE
# 24                            5.8  PORTO ALEGRE
#
#        pressao_atmosferica_ao_nivel_da_estacao,_horaria_(mb) region  \
# index
# 0                                                    NaN          S
# 24                                                1014.5          S
#
#        temperatura_do_ponto_de_orvalho_(°c)  \
# index
# 0                                       NaN
# 24                                     11.0
#
#        temperatura_mínima_na_hora_ant._(aut)_(°c)  \
# index
# 0                                             NaN
# 24                                           13.9
#
#        pressão_atmosferica_max.na_hora_ant._(aut)_(mb)  \
# index
# 0                                                  NaN
# 24                                              1014.5
#
#        temperatura_orvalho_max._na_hora_ant._(aut)_(°c)  \
# index
# 0                                                   NaN
# 24                                                 11.0
#
#        precipitação_total,_horário_(mm)  \
# index
# 0                                   NaN
# 24                                  0.0
#
#        umidade_rel._min._na_hora_ant._(aut)_(%)  longitude  \
# index
# 0                                           NaN -51.166667
# 24                                         69.0 -51.166667
#
#        umidade_relativa_do_ar,_horaria_(%) state  \
# index
# 0                                      NaN    RS
# 24                                    83.0    RS
#
#        umidade_rel._max._na_hora_ant._(aut)_(%)        data station_code  \
# index
# 0                                           NaN  2000-09-22         A801
# 24                                         83.0  2000-09-23         A801
#
#        temperatura_máxima_na_hora_ant._(aut)_(°c)  \
# index
# 0                                             NaN
# 24                                           14.7
#
#        vento,_direção_horaria_(gr)_(°_(gr))  vento,_velocidade_horaria_(m/s)  \
# index
# 0                                       NaN                              NaN
# 24                                    110.0                              2.8
#
#        latitude  pressão_atmosferica_min._na_hora_ant._(aut)_(mb)  \
# index
# 0        -30.05                                               NaN
# 24       -30.05                                            1014.2
#
#        temperatura_do_ar_-_bulbo_seco,_horaria_(°c)   hora  height
# index
# 0                                               NaN  00:00   46.97
# 24                                             13.9  00:00   46.97
